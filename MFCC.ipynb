# %%
import os
import sys
import re

import numpy as np
import matplotlib.pyplot as plt
import librosa

# %%
# load wave file and sampling frequency
y, sr = librosa.load('../voice/tsuchiya_normal/tsuchiya_normal_001.wav')

plt.plot(y)

# %%
mfcc = librosa.feature.mfcc(y)
plt.plot(mfcc)
print(y)
# Out:
# C:\Users\R\AppData\Local\Temp/ipykernel_4092/3889914117.py:1: FutureWarning: Pass y=[-1.9052024e-05 -4.5117100e-05 -4.6519282e-05 ... -9.5409234e-07
#  -1.9325946e-06  0.0000000e+00] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc = librosa.feature.mfcc(y)
# [-1.9052024e-05 -4.5117100e-05 -4.6519282e-05 ... -9.5409234e-07
#  -1.9325946e-06  0.0000000e+00]
